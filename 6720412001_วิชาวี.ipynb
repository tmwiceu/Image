# %% [markdown]
# <a href="https://colab.research.google.com/github/tmwiceu/Image/blob/main/6720412001_%E0%B8%A7%E0%B8%B4%E0%B8%8A%E0%B8%B2%E0%B8%A7%E0%B8%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install duckdb

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
df['item_price'] = df['item_price'].str.replace('$', '').astype(float)

# %%
x = duckdb.query("SELECT * FROM df").df()
x.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                               None        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                               None        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ## **อยากรู้ว่าเมนูในกลุ่มใดทำรายได้ได้มากที่สุด**

# %%
rev = duckdb.query(query).df()

fig = px.pie(rev, names='category', values='revenue',
             color_discrete_sequence=px.colors.qualitative.Pastel,
             title=' Revenue Share by Menu Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **อยากรู้ยอดขายสูงสุด 10 เมนู**

# %%
fig = px.bar(
    top_revenue,
    x='total_revenue',
    y='item_name',
    orientation='h',
    text='total_revenue',
    color='total_revenue',
    color_continuous_scale='sunset',
    title='Top 10 Items by Revenue',
    category_orders={'item_name': top_revenue.sort_values('total_revenue', ascending=False)['item_name'].tolist()}
)

fig.update_traces(texttemplate='$%{text:,.2f}', textposition='outside')
fig.update_layout(
    xaxis_title='Revenue ($)',
    yaxis_title='',
    coloraxis_showscale=False,
    template='plotly_white',
    height=550
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
